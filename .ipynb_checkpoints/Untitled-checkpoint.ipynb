# %% [markdown]
# _**Imports for document extraction, text processing, and writing the text into chunks**_

# %%
import os
from pathlib import Path
import re
import PyPDF2
import pandas as pd

# %% [markdown]
# _**Necessary functions for the document preprocessing and text clean up**_

# %%
def extract_text_from_pdf(pdf_path: Path) -> str:
    """
    Extract text from a PDF file
    """
    if pdf_path.suffix.lower() == ".pdf":
        text = ""
        with pdf_path.open("rb") as file:
            reader = PyPDF2.PdfReader(file)
            for page in reader.pages:
                text += page.extract_text()
        return text



def clean_text(text: str) -> str:
    """
    Clean the text by removing unnecesary sections
    """
    match = re.search(r'Bibliography|Acknowledgements|Index|Contents|Carbon', text, re.IGNORECASE)
    if match:
        text = text[match.start():]
    return text




def chunk_text(text: str, max_chunk_size: int = 2500) -> list[str]:
    """
    Chunk the text into smaller chunks of max_chunk_size
    """
    paragraphs = text.split(".\n")
    chunks=[]
    current_chunk=""
    for paragraph in paragraphs:
        if len(current_chunk) + len(paragraph) + 1 > max_chunk_size:
            chunks.append(current_chunk.strip())
            current_chunk = paragraph + "\n\n"
        else:
            current_chunk += paragraph + "\n\n"
    if current_chunk:
        chunks.append(current_chunk.strip())
    return chunks

# %% [markdown]
# _**Adding document text to a list of chunks which will then be processed by BERTopic**_

# %%
folder_year_2013_2016 = Path("ESG_reports/Siemens/2013-2016")
folder_year_2017_2020 = Path("ESG_reports/Siemens/2017-2020")
folder_year_2021_2024 = Path("ESG_reports/Siemens/2021-2024")
document_text_2016 = []
document_text_2020 = []
document_text_2024 = []

# %%
for file in folder_year_2013_2016.glob("*.pdf"):
    text = extract_text_from_pdf(file)
    cleaned_text = clean_text(text)
    chunks = chunk_text(text)
    for chunk in chunks:
        document_text_2016.append(chunk)
print("Done")

for file in folder_year_2017_2020.glob("*.pdf"):
    text = extract_text_from_pdf(file)
    cleaned_text = clean_text(text)
    chunks = chunk_text(text)
    for chunk in chunks:
        document_text_2020.append(chunk)
print("Done 2")

for file in folder_year_2021_2024.glob("*.pdf"):
    text = extract_text_from_pdf(file)
    cleaned_text = clean_text(text)
    chunks = chunk_text(text)
    for chunk in chunks:
        document_text_2024.append(chunk)
print("Done 3")
# Out:
# Done
# Done 2
# Done 3

# %% [markdown]
# _**Necessary imports for BERTopic**_

# %%
from sklearn.feature_extraction.text import CountVectorizer
from hdbscan import HDBSCAN
from umap import UMAP
from bertopic.representation import KeyBERTInspired
from flair.embeddings import TransformerDocumentEmbeddings
from bertopic import BERTopic

# %% [markdown]
# _**Configurations for the steps of BERTopic**_

# %%
cluster_model = HDBSCAN(min_cluster_size=20, min_samples=10,metric='euclidean')
umap_model = UMAP(random_state=42)
vectorizer_model = CountVectorizer(stop_words='english')
representation_model=KeyBERTInspired()

# %%
topic_model = BERTopic(embedding_model='all-MiniLM-L6-v2',
                       umap_model=umap_model, vectorizer_model=vectorizer_model)
topics, probabilities = topic_model.fit_transform(document_text_2020)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                            Name  \
# 0      -1    391                     -1_siemens_fiscal_tax_board
# 1       0     67                        0_100_gmbh_siemens_nited
# 2       1     56      1_emissions_environmental_carbon_portfolio
# 3       2     55                  2_human_rights_suppliers_chain
# 4       3     51  3_sustainability_sustainable_world_development
# 5       4     40              4_audit_group_statements_financial
# 6       5     36             5_100_gmbh_arrangements_contractual
# 7       6     35                    6_shares_cash_income_capital
# 8       7     34            7_contract_estimates_contracts_costs
# 9       8     32                   8_stock_awards_target_granted
# 10      9     31                     9_income_assets_fiscal_year
# 11     10     31                   10_orders_revenue_year_growth
# 12     11     29                   11_rate_risk_currency_foreign
# 13     12     29             12_board_supervisory_shall_managing
# 14     13     28                13_water_waste_consumption_sites
# 15     14     26          14_risk_risks_opportunities_management
# 16     15     25              15_safety_health_occupational_work
# 17     16     25            16_financial_fair_assets_instruments
# 18     17     25       17_digital_division_industries_mindsphere
# 19     18     24              18_compensation_target_bonus_board
# 20     19     22                        19_expect_fiscal_eps_net
# 21     20     22   20_healthcare_healthineers_services_providers
# 22     21     21                    21_india_100_limited_private
# 23     22     21         22_chairman_positions_board_supervisory
# 24     23     19             23_diversity_women_employees_people
# 25     24     17                             24_000_500_140_2017
# 26     25     16     25_compliance_corruption_integrity_business
# 27     26     16              26_shareholders_code_meeting_board
# 28     27     16              27_lcas_product_life_environmental
# 29     28     16           28_learning_education_training_people
# 30     29     15                   29_instruments_rate_fixed_sep
# 31     30     15     30_compliance_integrity_training_priorities
# 32     31     15          31_goodwill_generating_cash_impairment
# 33     32     14             32_million_equity_investments_joint
# 34     33     13     33_reporting_report_portfolio_environmental
# 35     34     12     34_regulations_countries_sanctions_business
# 36     35     12                  35_pension_bsav_managing_board
# 37     36     11                 36_customer_sdg_customers_score
# 38     37     11                     37_ltda_court_damages_paulo
# 39     38     11                     38_dividend_debt_income_net
#
#                                        Representation  \
# 0   [siemens, fiscal, tax, board, business, 2018, ...
# 1   [100, gmbh, siemens, nited, states, spain, lim...
# 2   [emissions, environmental, carbon, portfolio, ...
# 3   [human, rights, suppliers, chain, supply, sust...
# 4   [sustainability, sustainable, world, developme...
# 5   [audit, group, statements, financial, report, ...
# 6   [100, gmbh, arrangements, contractual, siemens...
# 7   [shares, cash, income, capital, stock, bonds, ...
# 8   [contract, estimates, contracts, costs, procee...
# 9   [stock, awards, target, granted, attainment, p...
# 10  [income, assets, fiscal, year, 2017, million, ...
# 11  [orders, revenue, year, growth, order, profit,...
# 12  [rate, risk, currency, foreign, credit, financ...
# 13  [board, supervisory, shall, managing, committe...
# 14  [water, waste, consumption, sites, wastewater,...
# 15  [risk, risks, opportunities, management, erm, ...
# 16  [safety, health, occupational, work, employees...
# 17  [financial, fair, assets, instruments, value, ...
# 18  [digital, division, industries, mindsphere, sy...
# 19  [compensation, target, bonus, board, stock, ma...
# 20  [expect, fiscal, eps, net, industrial, range, ...
# 21  [healthcare, healthineers, services, providers...
# 22  [india, 100, limited, private, chennai, china,...
# 23  [chairman, positions, board, supervisory, 31, ...
# 24  [diversity, women, employees, people, bias, wo...
# 25  [000, 500, 140, 2017, 065, compensation, dr, s...
# 26  [compliance, corruption, integrity, business, ...
# 27  [shareholders, code, meeting, board, governanc...
# 28  [lcas, product, life, environmental, cycle, su...
# 29  [learning, education, training, people, progra...
# 30  [instruments, rate, fixed, sep, 750, fix, temb...
# 31  [compliance, integrity, training, priorities, ...
# 32  [goodwill, generating, cash, impairment, units...
# 33  [million, equity, investments, joint, interest...
# 34  [reporting, report, portfolio, environmental, ...
# 35  [regulations, countries, sanctions, business, ...
# 36  [pension, bsav, managing, board, benefit, memb...
# 37  [customer, sdg, customers, score, development,...
# 38  [ltda, court, damages, paulo, são, public, all...
# 39  [dividend, debt, income, net, shareholders, pl...
#
#                                   Representative_Docs
# 0   [Our reportable segments may do business with ...
# 1   [T\n.NET Houston, LLC, Austin, TX\n /\n U\nnit...
# 2   [The calculation of the reduction of carbon di...
# 3   [Index according to the ten principles of the ...
# 4   [Business to Society® – measuring our \nsocial...
# 5   [DETAILED DISCUSSION OF THE AUDIT  \nOF THE FI...
# 6   [2\n  Contr\nol due to rights to appoint, reas...
# 7   [The Company may not repurchase its own shares...
# 8   [Provisions for proceedings out of or in conne...
# 9   [4  For one half of the Siemens Stock Awards 2...
# 10  [The tax rate for fiscal 2017 was 26\n %, posi...
# 11  [Orders 12,749 11,875 7  % 7  %\nRevenue 10,22...
# 12  [According to the Company policy Siemens units...
# 13  [Taking the Company’s international orientatio...
# 14  [COMPLIANCE  \nTHIS REPORT PAGE 37Annex 59Unit...
# 15  [Risk management at Siemens builds on a compre...
# 16  [In our Health and Safety management, we place...
# 17  [Financial instruments  – A financial instrume...
# 18  [A.3.2  Digit al Industries\nThe Operating Com...
# 19  [A.10.1.2  REMUNERA TION OF MANAGING BOARD \nM...
# 20  [For our EPS guidance we assume these positive...
# 21  [For fiscal 2019, Siemens Healthineers expects...
# 22  [11\n  V\nalues according to the latest availa...
# 23  [Members of the Supervisory Board and position...
# 24  [SUPPLY CHAIN MANAGEMENT  \nTHIS REPORT, PAGE ...
# 25  [2019 2018\n(Amounts in €\n )Base  \ncompen\n-...
# 26  [Our Compliance System aims to ensure that our...
# 27  [As par t of our in\nvestor relations activiti...
# 28  [We plan to improve the coverage of life cycle...
# 29  [Keeping pace with the speed of change of know...
# 30  [CREDIT FACILITIES\nAs of September  30, 2018 ...
# 31  [Compliance Priorities in Fiscal 2018\nOur com...
# 32  [The determination of the recoverable amount o...
# 33  [Portfolio measures, at-equity investments, ot...
# 34  [REPORTING APPROACH\nThe ”Sustainability Infor...
# 35  [Regulatory risks and potential sanctions:  As...
# 36  [Managing Board members are eligible to receiv...
# 37  [Our efforts don’t stop there. We intensified ...
# 38  [As previously reported, in May  2013, Siemens...
# 39  [At the Annual Shareholders’ Meeting, the Mana...

# %%
df=topic_model.get_document_info(document_text_2020)
df
# Out:
#                                                Document  Topic  \
# 0     Annual Report  \n20\n18\nsiemens.com\nA.1 p 2 ...      9
# 1     T\no further increase the entrepreneurial free...     20
# 2     Our reportable segments may do business with e...     -1
# 3     In line with common practice in the financial ...     -1
# 4     A.2.4  Capit al structure\nSustainable revenue...     38
# ...                                                 ...    ...
# 1380  Profile of required skills and expertise\nThe ...     12
# 1381  Diversity\nWith regard to the composition of t...     12
# 1382  Limits on age and on length of membership\nIn ...     12
# 1383  The Supervisory Board is of the opinion that i...     12
# 1384  Due t o r\nounding, numbers presented througho...     -1
#
#                                                Name  \
# 0                       9_income_assets_fiscal_year
# 1     20_healthcare_healthineers_services_providers
# 2                       -1_siemens_fiscal_tax_board
# 3                       -1_siemens_fiscal_tax_board
# 4                       38_dividend_debt_income_net
# ...                                             ...
# 1380            12_board_supervisory_shall_managing
# 1381            12_board_supervisory_shall_managing
# 1382            12_board_supervisory_shall_managing
# 1383            12_board_supervisory_shall_managing
# 1384                    -1_siemens_fiscal_tax_board
#
#                                          Representation  \
# 0     [income, assets, fiscal, year, 2017, million, ...
# 1     [healthcare, healthineers, services, providers...
# 2     [siemens, fiscal, tax, board, business, 2018, ...
# 3     [siemens, fiscal, tax, board, business, 2018, ...
# 4     [dividend, debt, income, net, shareholders, pl...
# ...                                                 ...
# 1380  [board, supervisory, shall, managing, committe...
# 1381  [board, supervisory, shall, managing, committe...
# 1382  [board, supervisory, shall, managing, committe...
# 1383  [board, supervisory, shall, managing, committe...
# 1384  [siemens, fiscal, tax, board, business, 2018, ...
#
#                                     Representative_Docs  \
# 0     [The tax rate for fiscal 2017 was 26\n %, posi...
# 1     [For fiscal 2019, Siemens Healthineers expects...
# 2     [Our reportable segments may do business with ...
# 3     [Our reportable segments may do business with ...
# 4     [At the Annual Shareholders’ Meeting, the Mana...
# ...                                                 ...
# 1380  [Taking the Company’s international orientatio...
# 1381  [Taking the Company’s international orientatio...
# 1382  [Taking the Company’s international orientatio...
# 1383  [Taking the Company’s international orientatio...
# 1384  [Our reportable segments may do business with ...
#
#                                             Top_n_words  Probability  \
# 0     income - assets - fiscal - year - 2017 - milli...     1.000000
# 1     healthcare - healthineers - services - provide...     0.782722
# 2     siemens - fiscal - tax - board - business - 20...     0.000000
# 3     siemens - fiscal - tax - board - business - 20...     0.000000
# 4     dividend - debt - income - net - shareholders ...     1.000000
# ...                                                 ...          ...
# 1380  board - supervisory - shall - managing - commi...     0.739982
# 1381  board - supervisory - shall - managing - commi...     0.962484
# 1382  board - supervisory - shall - managing - commi...     0.963465
# 1383  board - supervisory - shall - managing - commi...     1.000000
# 1384  siemens - fiscal - tax - board - business - 20...     0.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                        True
# 3                       False
# 4                       False
# ...                       ...
# 1380                    False
# 1381                    False
# 1382                     True
# 1383                    False
# 1384                    False
#
# [1385 rows x 8 columns]

# %%
def concatenate_documents_by_topic(df: pd.DataFrame, n_docs: int = 3) -> pd.DataFrame:

    """

    Groups the DataFrame by 'Topic', and for each topic concatenates up to `n_docs`

    documents into a single string like: "Document 1: ... Document 2: ...".

 

 

    Parameters:

        df (pd.DataFrame): DataFrame with 'Topic' and 'Document' columns.

        n_docs (int): Number of documents to include per topic.

 

 

    Returns:

        pd.DataFrame: A DataFrame with columns ['Topic', 'ConcatenatedDocuments'].

    """

    result = []

 

 

    for topic, group in df.groupby("Topic"):

        docs = group["Document"].head(n_docs).tolist()

        concatenated = "\n\n".join([f"Document {i+1}: {doc}" for i, doc in enumerate(docs)])

        result.append({"Topic": topic, "ConcatenatedDocuments": concatenated})

 
    return pd.DataFrame(result)

# %%
df_2=concatenate_documents_by_topic(df)
df_2
# Out:
#     Topic                              ConcatenatedDocuments
# 0      -1  Document 1: Our reportable segments may do bus...
# 1       0  Document 1: 2 of t\nhe German \nCommercial Cod...
# 2       1  Document 1: Combating climate change is one of...
# 3       2  Document 1: WWW.SIEMENS.COM/INTEGRITY-INITIATI...
# 4       3  Document 1: Sustainability \nInformation 2017\...
# 5       4  Document 1: Our Consolidated Financial Stateme...
# 6       5  Document 1: 2 \n Contr\nol due to rights to ap...
# 7       6  Document 1: The main factors for the change in...
# 8       7  Document 1: Cost overruns or additional paymen...
# 9       8  Document 1: Beneficiaries receive one free sha...
# 10      9  Document 1: Annual Report  \n20\n18\nsiemens.c...
# 11     10  Document 1: Orders 13,717 13,329 3  % 12  %\nR...
# 12     11  Document 1: S. dollar\n. In addition, we are e...
# 13     12  Document 1: W\nith the support of the Chairman...
# 14     13  Document 1: We have been able to significantly...
# 15     14  Document 1: Overall, the actual development fo...
# 16     15  Document 1: Siemens product schools work with ...
# 17     16  Document 1: Inventories  – Inventories are val...
# 18     17  Document 1: R & D activities of the Division f...
# 19     18  Document 1: Remuneration system for Managing B...
# 20     19  Document 1: We were again very successful in e...
# 21     20  Document 1: T\no further increase the entrepre...
# 22     21  Document 1: 11\n  V\nalues according to the la...
# 23     22  Document 1: The regular terms of office of sev...
# 24     23  Document 1: With this, Siemens lays the founda...
# 25     24  Document 1: Roland Busch €\n 1,785,096 \n(2017...
# 26     25  Document 1: Our responsible business practices...
# 27     26  Document 1: A.9.3  Corpor ate Governance \n s\...
# 28     27  Document 1: 6.4 Product Stewardship \nResource...
# 29     28  Document 1: The Siemens Global Learning Campus...
# 30     29  Document 1: NOTE 10  Contr act assets and liab...
# 31     30  Document 1: To be effective, our Compliance Sy...
# 32     31  Document 1: Goodwill  – Goodwill is not amorti...
# 33     32  Document 1: Portfolio measures, at-equity inve...
# 34     33  Document 1: REPORTING APPROACH\nThe ”Sustainab...
# 35     34  Document 1: Audits by tax authorities and chan...
# 36     35  Document 1: Pension benefit commitments\nLike ...
# 37     36  Document 1: There is follow-up, both internall...
# 38     37  Document 1: NOTE 22  Leg al proceedings\nPROCE...
# 39     38  Document 1: A.2.4  Capit al structure\nSustain...

# %%
first_value = df_2["ConcatenatedDocuments"].iloc[0]
# Out:
# <class 'str'>

# %%
open_ai_key="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"
import openai

# Option 1: Store your API key as an environment variable
# export OPENAI_API_KEY="your_api_key_here" (in terminal or .env file)
openai.api_key = open_ai_key

def summarize_paragraph(paragraph, model="gpt-4.1-mini"):
    prompt = f"Summarize the following paragraph in 2-3 sentences:\n\n{paragraph}"

    response = openai.responses.create(
        model=model,
        input=[
            {"role": "user", "content": prompt}
        ]
    )
    
    summary = response.output[0].content[0].text
    return summary


summary = summarize_paragraph(first_value)
print("Summary:\n",summary)
# Out:
# Summary:
#  The Siemens Group's report outlines its organizational structure, non-financial policies, and enhanced financial framework effective from April 2019, targeting annual revenue growth of 4-5% and improved profit margins across various business segments. The company uses measures like return on equity (ROE) and return on capital employed (ROCE) to manage capital efficiency, aiming for a long-term ROCE between 15-20%. Additionally, the method for calculating capital employed and interim ROCE is detailed, with adjustments following the adoption of IFRS 9 standards.
